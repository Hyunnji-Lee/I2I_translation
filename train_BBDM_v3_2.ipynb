# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/root        49G   45G  4.2G  92% /
# devtmpfs        1.8G     0  1.8G   0% /dev
# tmpfs           1.8G     0  1.8G   0% /dev/shm
# tmpfs           366M  1.2M  365M   1% /run
# tmpfs           5.0M     0  5.0M   0% /run/lock
# tmpfs           1.8G     0  1.8G   0% /sys/fs/cgroup
# /dev/loop0       45M   45M     0 100% /snap/snapd/23545
# /dev/loop3       64M   64M     0 100% /snap/core20/2434
# /dev/loop1       92M   92M     0 100% /snap/lxd/29619
# /dev/sda15      105M  6.1M   99M   6% /boot/efi
# tmpfs           366M   20K  366M   1% /run/user/124
# /dev/loop4      391M  391M     0 100% /snap/google-cloud-cli/301
# /dev/loop5      391M  391M     0 100% /snap/google-cloud-cli/303
# tmpfs           366M  4.0K  366M   1% /run/user/1002

# %%
# !rm -rf ~/.local/share/Trash/*

# %%
# !python3 main.py --config configs/Template-LBBDM-f16-v3_2.yaml --train --sample_at_start --save_top --gpu_ids 0
# Out:
# save training results to results/CBCT2CT_translation_v3_2/LBBDM-f16/
# Working with z of shape (1, 8, 16, 16) = 2048 dimensions.
# ...

# %%
# !python3 main.py --config configs/Template-LBBDM-f16-v3_2.yaml --train --sample_at_start --save_top --gpu_ids 0 \
--resume_model results/CBCT2CT_translation_v3_2/LBBDM-f16/checkpoint/latest_model_6.pth \
--resume_optim results/CBCT2CT_translation_v3_2/LBBDM-f16/checkpoint/latest_optim_sche_6.pth
# Out:
# save training results to results/CBCT2CT_translation_v3_2/LBBDM-f16/
# Working with z of shape (1, 8, 16, 16) = 2048 dimensions.
# ...

# %%
tensorboard --logdir=BBDM/results/CBCT2CT_translation_v3_2/LBBDM-f16/log --bind_all --port=6006

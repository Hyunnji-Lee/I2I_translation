# %% [markdown]
# ### first case : epoch=50

# %%
# === Metrics 계산 ===
import numpy as np
from evaluation.Evaluation_synthrad import ImageMetrics

label_save_path = 'results/CBCT2CT_translation/LBBDM-f16/sample_to_eval/ground_truth'
output_save_path = 'results/CBCT2CT_translation/LBBDM-f16/sample_to_eval/200' 
mask_save_path = 'brain_data/test/mask'  

metrics = ImageMetrics()
sample_num = 1 #number of testing sample

# %%
import os

gt_files = sorted(os.listdir(label_save_path))
pred_files = sorted(os.listdir(output_save_path))
mask_files = sorted(os.listdir(mask_save_path))

scores = {'mae': [], 'ssim': [], 'psnr': [], 'cnr':[]}

for gt_file, pred_file, mask_file in zip(gt_files, pred_files, mask_files):
    gt_full_path = os.path.join(label_save_path, gt_file)
    mask_full_path = os.path.join(mask_save_path, mask_file)
    pred_full_path = os.path.join(output_save_path, pred_file)
    score = metrics.score_patient(gt_full_path, pred_full_path, mask_full_path)

    for key in scores:
        scores[key].append(score[key])

# print mean value
print("=== Evaluation Metrics ===")
for metric, values in scores.items():
    print(f'{metric}: {np.mean(values):.4f}')
# Out:
# === Evaluation Metrics ===
# mae: 192.4663
# ssim: 0.6662
# psnr: 21.2479
# cnr: 1.4060

# %%
import matplotlib.pyplot as plt
import os

gt_files = sorted(os.listdir(label_save_path))
pred_files = sorted(os.listdir(output_save_path))
mask_files = sorted(os.listdir(mask_save_path))

input_save_path = 'results/CBCT2CT_translation/LBBDM-f16/sample_to_eval/condition'
input_files = sorted(os.listdir(input_save_path))

for input_file, gt_file, pred_file in zip(input_files[20:40], gt_files[20:40], pred_files[20:40]):
    pred = np.load(os.path.join(output_save_path, pred_file))
    gt = np.load(os.path.join(label_save_path, gt_file))
    input = np.load(os.path.join(input_save_path, input_file))
    
    plt.figure()
    
    plt.subplot(1,3,1)
    plt.imshow(input[:,:,0], cmap='gray')
    plt.title(input_file)
    plt.axis('off')
    
    plt.subplot(1,3,2)
    plt.imshow(pred[:,:,0], cmap='gray')
    plt.title(pred_file)
    plt.axis('off')
    
    plt.subplot(1,3,3)
    plt.imshow(gt[:,:,0], cmap='gray')
    plt.title(gt_file)
    plt.axis('off')

# %% [markdown]
# ### first case : epoch=100

# %%
# === Metrics 계산 ===
import numpy as np
from evaluation.Evaluation_synthrad import ImageMetrics

label_save_path = 'results/CBCT2CT_translation/LBBDM-f16/sample_to_eval/ground_truth'
output_save_path = 'results/CBCT2CT_translation/LBBDM-f16/sample_to_eval/200' 
mask_save_path = 'brain_data/test/mask'  

metrics = ImageMetrics()
sample_num = 1 #number of testing sample

# %%
import os

gt_files = sorted(os.listdir(label_save_path))
pred_files = sorted(os.listdir(output_save_path))
mask_files = sorted(os.listdir(mask_save_path))

scores = {'mae': [], 'ssim': [], 'psnr': [], 'cnr':[]}

for gt_file, pred_file, mask_file in zip(gt_files, pred_files, mask_files):
    gt_full_path = os.path.join(label_save_path, gt_file)
    mask_full_path = os.path.join(mask_save_path, mask_file)
    pred_full_path = os.path.join(output_save_path, pred_file)
    score = metrics.score_patient(gt_full_path, pred_full_path, mask_full_path)

    for key in scores:
        scores[key].append(score[key])

# print mean value
print("=== Evaluation Metrics ===")
for metric, values in scores.items():
    print(f'{metric}: {np.mean(values):.4f}')
# Out:
# === Evaluation Metrics ===
# mae: 198.1853
# ssim: 0.6643
# psnr: 21.1283
# cnr: 1.3916

# %%
import matplotlib.pyplot as plt
input_save_path = 'results/CBCT2CT_translation/LBBDM-f16/sample_to_eval/condition'
input_files = sorted(os.listdir(input_save_path))

for input_file, gt_file, pred_file in zip(input_files[30:50], gt_files[30:50], pred_files[30:50]):
    pred = np.load(os.path.join(output_save_path, pred_file))
    gt = np.load(os.path.join(label_save_path, gt_file))
    input = np.load(os.path.join(input_save_path, input_file))
    
    plt.figure()
    
    plt.subplot(1,3,1)
    plt.imshow(input[:,:,0], cmap='gray')
    plt.title(input_file)
    plt.axis('off')
    
    plt.subplot(1,3,2)
    plt.imshow(pred[:,:,0], cmap='gray')
    plt.title(pred_file)
    plt.axis('off')
    
    plt.subplot(1,3,3)
    plt.imshow(gt[:,:,0], cmap='gray')
    plt.title(gt_file)
    plt.axis('off')

# %%
# CBCT로 평가

input_save_path = 'results/CBCT2CT_translation/LBBDM-f16/sample_to_eval/condition'

gt_files = sorted(os.listdir(label_save_path))
input_files = sorted(os.listdir(input_save_path))
mask_files = sorted(os.listdir(mask_save_path))

scores = {'mae': [], 'ssim': [], 'psnr': [], 'cnr':[]}

for gt_file, input_file, mask_file in zip(gt_files, input_files, mask_files):
    gt_full_path = os.path.join(label_save_path, gt_file)
    mask_full_path = os.path.join(mask_save_path, mask_file)
    
    input_full_path = os.path.join(input_save_path, input_file)
    score = metrics.score_patient(gt_full_path, input_full_path, mask_full_path)

    for key in scores:
        scores[key].append(score[key])

# print mean value
print("=== Evaluation Metrics ===")
for metric, values in scores.items():
    print(f'{metric}: {np.mean(values):.4f}')
# Out:
# === Evaluation Metrics ===
# mae: 461.7969
# ssim: 0.7085
# psnr: 20.6509
# cnr: 1.3963

# %%
# shape, value check
import os
import PIL.Image as Image

pred_files = sorted(os.listdir(output_save_path))
pred_file = pred_files[0]
pred_full_path = os.path.join(output_save_path, pred_file)

gt_files = sorted(os.listdir(label_save_path))
gt_file = gt_files[0]
gt_full_path = os.path.join(label_save_path, gt_file)

pred = np.load(pred_full_path)
gt = np.load(gt_full_path)

print(np.max(pred), np.min(pred))
print(pred.shape)

print(np.max(gt), np.min(gt))
print(gt.shape)
print(gt.ndim)

mask_files = sorted(os.listdir(mask_save_path))
mask_file = mask_files[0]
mask_full_path = os.path.join(mask_save_path, mask_file)
mask = np.load(mask_full_path)
print(np.max(mask))
print(mask.shape)

from skimage.transform import resize
mask_array = resize(mask, gt.shape)
print(mask_array.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 import os
#       3 import PIL.Image as Image
# ----> 5 pred_files = sorted(os.listdir(output_save_path))
#       6 pred_file = pred_files[0]
#       7 pred_full_path = os.path.join(output_save_path, pred_file)
#
# NameError: name 'output_save_path' is not defined

# %%
max_ct, min_ct = 3000, -1024

gt_array = (gt/255)*(max_ct-min_ct) + min_ct
pred_array = (pred/255)*(max_ct-min_ct) + min_ct

print(np.max(gt))
print(np.max(pred))
print(np.max(gt_array))
print(np.max(pred_array))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 max_ct, min_ct = 3000, -1024
# ----> 3 gt_array = (gt/255)*(max_ct-min_ct) + min_ct
#       4 pred_array = (pred/255)*(max_ct-min_ct) + min_ct
#       6 print(np.max(gt))
#
# NameError: name 'gt' is not defined

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/root        49G   27G   22G  56% /
# devtmpfs        1.8G     0  1.8G   0% /dev
# tmpfs           1.8G     0  1.8G   0% /dev/shm
# tmpfs           366M  1.2M  365M   1% /run
# tmpfs           5.0M     0  5.0M   0% /run/lock
# tmpfs           1.8G     0  1.8G   0% /sys/fs/cgroup
# /dev/loop0       45M   45M     0 100% /snap/snapd/23545
# /dev/loop2      390M  390M     0 100% /snap/google-cloud-cli/297
# /dev/loop3       64M   64M     0 100% /snap/core20/2434
# /dev/loop1       92M   92M     0 100% /snap/lxd/29619
# /dev/sda15      105M  6.1M   99M   6% /boot/efi
# tmpfs           366M   20K  366M   1% /run/user/124
# /dev/loop4      391M  391M     0 100% /snap/google-cloud-cli/301
# tmpfs           366M  4.0K  366M   1% /run/user/1002

# %%
# 이전버전 BBDM 평가

gt_files = sorted(os.listdir(label_save_path))
pred_files = sorted(os.listdir(output_save_path))
mask_files = sorted(os.listdir(mask_save_path))

scores = {'mae': [], 'ssim': [], 'psnr': [], 'cnr':[]}

for gt_file, pred_file, mask_file in zip(gt_files, pred_files, mask_files):
    gt_full_path = os.path.join(label_save_path, gt_file)
    mask_full_path = os.path.join(mask_save_path, mask_file)
    
    pred_full_path = os.path.join(output_save_path, pred_file,'output_0.png')
    score = metrics.score_patient(gt_full_path, pred_full_path, mask_full_path)

    for key in scores:
        scores[key].append(score[key])

# print mean value
print("=== Evaluation Metrics ===")
for metric, values in scores.items():
    print(f'{metric}: {np.mean(values):.4f}')
# Out:
# === Evaluation Metrics ===
# mae: 16.1976
# ssim: 0.9822
# psnr: 43.9274
# cnr: 1.4387

# %%
# 이전버전 BBDM - 후처리 이후 평가

gt_files = sorted(os.listdir(label_save_path))
pred_files = sorted(os.listdir(output_save_path))
mask_files = sorted(os.listdir(mask_save_path))

scores = {'mae': [], 'ssim': [], 'psnr': [], 'cnr':[]}

for gt_file, pred_file, mask_file in zip(gt_files, pred_files, mask_files):
    gt_full_path = os.path.join(label_save_path, gt_file)
    mask_full_path = os.path.join(mask_save_path, mask_file)
    
    pred_full_path = os.path.join(output_save_path, pred_file,'output_1.png')
    score = metrics.score_patient(gt_full_path, pred_full_path, mask_full_path)

    for key in scores:
        scores[key].append(score[key])

# print mean value
print("=== Evaluation Metrics ===")
for metric, values in scores.items():
    print(f'{metric}: {np.mean(values):.4f}')
# Out:
# === Evaluation Metrics ===
# mae: 256.6573
# ssim: 0.6058
# psnr: 19.9292
# cnr: 1.4361

# %%
# 이전버전 CBCT로 평가

input_save_path = 'results/synthrad/LBBDM-f16/sample_to_eval/condition'

gt_files = sorted(os.listdir(label_save_path))
input_files = sorted(os.listdir(input_save_path))
mask_files = sorted(os.listdir(mask_save_path))

scores = {'mae': [], 'ssim': [], 'psnr': [], 'cnr':[]}

for gt_file, input_file, mask_file in zip(gt_files, input_files, mask_files):
    gt_full_path = os.path.join(label_save_path, gt_file)
    mask_full_path = os.path.join(mask_save_path, mask_file)
    
    input_full_path = os.path.join(input_save_path, input_file)
    score = metrics.score_patient(gt_full_path, input_full_path, mask_full_path)

    for key in scores:
        scores[key].append(score[key])

# print mean value
print("=== Evaluation Metrics ===")
for metric, values in scores.items():
    print(f'{metric}: {np.mean(values):.4f}')
# Out:
# === Evaluation Metrics ===
# mae: 372.1134
# ssim: 0.6871
# psnr: 20.6283
# cnr: 1.3931
